# %%
def museo(e,o):
 if (4<=e<=16):
  if (o==1):
   pe16_1=50-(50*0.1)
   return pe16_1
  if (o==2):
   pe16_2=50-(50*0.3)
   return pe16_2
  if (o==3):
   pe16_3=50-(50*0.5)
   return pe16_3
 elif (16<e):
  if (o==1):
   pe17_1=100-(100*0.1)
   return pe17_1
  if (o==2):
   pe17_2=100-(100*0.3)
   return pe17_2
  if (o==3):
   pe17_3=100-(100*0.5)
   return pe17_3

e=int (input("Ingresa la edad en años cumplidos:"))
if (0<e<4):
  print("ENTRADA GRATUITA")
else:
  o=int (input("Ingresa la opcupación del visitante: \n"
  "1.-Estudiante con credencial \n"
  "2.-Docente con credencial \n"
  "3.-INAPAM \n" ))
  print("El costo de entrada es:",museo(e,o),'pesos')
# Out:
# Ingresa la edad en años cumplidos:17
# Ingresa la opcupación del visitante:
# 1.-Estudiante con credencial
# 2.-Docente con credencial
# 3.-INAPAM
# 1
# El costo de entrada es: 90.0 pesos
