# %%
def area(rad):
 A=3.1416*(rad**2)
 return A;
def volumen(rad,h):
 V=area(rad)*h
 return V;

rad=float (input("Ingresa el radio del círculo: "))
h=float (input("Ingresa la altura del cilindro: "))
print("El área del círculo es:",area(rad))
print("El volumen del cilindro es:",volumen(rad,h))
# Out:
# Ingresa el radio del círculo: 5
# Ingresa la altura del cilindro: 7
# El área del círculo es: 78.53999999999999
# El volumen del cilindro es: 549.78
