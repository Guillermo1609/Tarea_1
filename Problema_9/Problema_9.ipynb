# %%
def f(n,c):
  if (n>0):
   while (1<c):
     c-=1
     n*=c
     f=n
   return f; 
  elif (n<0):
    while (-1>c):
     c+=1
     n*=c
     fn=n
    return fn;

n=int (input("Ingresa un numero entero: "))
c=n
print("El factorial del numero ingresado es:",f(n,c))
# Out:
# Ingresa un numero entero: 32
# El factorial del numero ingresado es: 263130836933693530167218012160000000
