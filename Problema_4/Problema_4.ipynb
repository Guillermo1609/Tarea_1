# %%
def calculadora(a,b,op):
 if op==1:
   suma=a+b
   print("El resultado es",suma,"por que:",a,"+",b,"=",suma)
 elif op==2:
   resta=a-b
   print("El resultado es",resta,"por que:",a,"-",b,"=",resta)
 elif op==3:
   multiplicar=a*b
   print("El resultado es",multiplicar,"por que:",a,"x",b,"=", multiplicar) 
 elif op==4:
   while (b==0):
      b=int(input("Ingresa un nuevo valor para b ya que no se puede dividir entre 0:"))
   dividir=a/b
   print("El resultado es ",dividir,"por que:",a,"/",b,"=",dividir)

 
print("            *****MENU DE OPERACIONES MATEMÁTICAS*****                ")
print("1.-SUMA")
print("2.-RESTA")
print("3.-MULTIPLICACIÓN")
print("4.-DIVISIÓN \n\n\n")

op=int(input("Ingresa una operacion:"))
while (op>4 or op<=0):
 op=int (input("La opción que desea no existe, ingresa una nueva opción:"))
a=float(input("Ingresa valor de a:"))
b=float(input("Ingresa valor de b:"))
calculadora(a,b,op)
# Out:
#             *****MENU DE OPERACIONES MATEMÁTICAS*****
# 1.-SUMA
# 2.-RESTA
# 3.-MULTIPLICACIÓN
# 4.-DIVISIÓN
