# %%
def pago(pxh,h):
 pxd=pxh*h
 pxs=pxd*5
 pxm=pxs*4
 print("El pago por dia es:",pxd)
 print("El pago por semana es:",pxs)
 print("El pago por mes es:",pxm)

pxh=150.0
h=float (input("Ingresa el numero de horas:"))
pago(pxh,h)
# Out:
# Ingresa el numero de horas:5
# El pago por dia es: 750.0
# El pago por semana es: 3750.0
# El pago por mes es: 15000.0
