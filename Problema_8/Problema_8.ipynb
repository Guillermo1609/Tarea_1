# %%
def triangulo(n,c):
 while (0<c<=n):
  print('*'*c)
  c+=1

n=int (input("Ingresa un numero entero: "))
c=1
triangulo(n,c)
# Out:
# Ingresa un numero entero: 8
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
