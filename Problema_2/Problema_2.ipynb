# %%
def cadena(esc,vec):
 cont=0
 while cont<vec:
  cont+=1
  print(esc)

esc=str (input("Ingresa lo que deseas ver:"))
vec=int (input("Veces de repeticiones:"))
cadena(esc,vec)
# Out:
# Ingresa lo que deseas ver:paseme prof
# Veces de repeticiones:5
# paseme prof
# paseme prof
# paseme prof
# paseme prof
# paseme prof
