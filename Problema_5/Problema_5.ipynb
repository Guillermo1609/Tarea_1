# %%
def tienda (n_p,n_jm,pedidos):
  peso_p=n_p*150
  peso_jm=n_jm*170
  peso_tot=peso_p+peso_jm
  print("°El peso del pedido",num_pedidos,"es:",peso_tot,"gramos°")
  if (peso_tot>10000):
   g_extra=peso_tot-10000
   print("ERROR: el pedido sobrepasa a los 10kg por",g_extra,"gramos extra")
   return False;
    

num_pedidos=0
pedidos=int (input("Ingresa el número de pedidos:")) 
while (num_pedidos<pedidos):
  num_pedidos+=1
  print("*** Pedido número",num_pedidos,"***")
  n_p=int (input("--Cantidad de payasos:")) 
  n_jm=int (input("--Cantidad de juegos de mesa:"))
  print(tienda (n_p,n_jm,pedidos))
# Out:
# Ingresa el número de pedidos:4
# *** Pedido número 1 ***
# --Cantidad de payasos:3
# --Cantidad de juegos de mesa:2
# °El peso del pedido 1 es: 790 gramos°
# None
# *** Pedido número 2 ***
# --Cantidad de payasos:55
# --Cantidad de juegos de mesa:23
# °El peso del pedido 2 es: 12160 gramos°
# ERROR: el pedido sobrepasa a los 10kg por 2160 gramos extra
# False
# *** Pedido número 3 ***
# --Cantidad de payasos:3
# --Cantidad de juegos de mesa:8
# °El peso del pedido 3 es: 1810 gramos°
# None
# *** Pedido número 4 ***
# --Cantidad de payasos:32
# --Cantidad de juegos de mesa:32
# °El peso del pedido 4 es: 10240 gramos°
# ERROR: el pedido sobrepasa a los 10kg por 240 gramos extra
# False
